# %% [markdown]
# # Bird distributions

# %% [markdown]
# Visualize the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
birds = pd.read_csv('../birds.csv')
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %% [markdown]
# In general, you can quickly look at the way data is distributed by using a scatter plot as we did in the previous lesson:

# %%
birds.plot(kind='scatter',x='MaxLength',y='Order',figsize=(12,8))

plt.title('Max Length per Order')
plt.ylabel('Order')
plt.xlabel('Max Length')

plt.show()

# %% [markdown]
# Show a histogram of the MaxBodyMass data

# %%
birds['MaxBodyMass'].plot(kind = 'hist',bins = 10,figsize = (12,12))
plt.show()

# %% [markdown]
# Experiment with bins

# %%
birds['MaxBodyMass'].plot(kind = 'hist',bins = 30,figsize = (12,12))
plt.show()

# %% [markdown]
# Filter the data and create a new (body mass is under 60, and show 40 bins)

# %%
filteredBirds = birds[(birds['MaxBodyMass'] > 1) & (birds['MaxBodyMass'] < 60)]      
filteredBirds['MaxBodyMass'].plot(kind = 'hist',bins = 40,figsize = (10,10))
plt.show()

# %% [markdown]
#  Try some other filters and data points. To see the full distribution of the data, remove the ['MaxBodyMass'] filter to show labeled distributions.

# %%
filteredBirds = birds[birds['MaxWingspan'] < 100]    # filter on maxwingspan 
filteredBirds['MaxWingspan'].plot(kind = 'hist',bins = 50,figsize = (7,7))
plt.show()

# %%
filteredBirds = birds[birds['MaxWingspan'] < 100]    
filteredBirds['MaxLength'].plot(kind = 'hist',bins = 50,figsize = (7,7))
plt.show()

# %%
filteredBirds = birds[birds['MaxBodyMass'] < 100]    #filter on maxbodymass
filteredBirds['MaxBodyMass'].plot(kind = 'hist',bins = 50,figsize = (7,7))
plt.show()

# %% [markdown]
# Create a 2D histgram showing the relationship between MaxBodyMass and MaxLength

# %%
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

x = filteredBirds['MaxBodyMass']
y = filteredBirds['MaxLength']

fig, ax = plt.subplots(tight_layout=True)

hist = ax.hist2d(x, y)

# %% [markdown]
# Working with the filtered dataset, create a labelled and stacked histogram superimposing ConservationStatus with MaxBodyMass

# %%
filteredBirds = birds[(birds['MaxBodyMass'] > 1) & (birds['MaxBodyMass'] < 60)]    
x1 = filteredBirds.loc[filteredBirds.ConservationStatus=='EX', 'MinWingspan']
x2 = filteredBirds.loc[filteredBirds.ConservationStatus=='CR', 'MinWingspan']
x3 = filteredBirds.loc[filteredBirds.ConservationStatus=='EN', 'MinWingspan']
x4 = filteredBirds.loc[filteredBirds.ConservationStatus=='NT', 'MinWingspan']
x5 = filteredBirds.loc[filteredBirds.ConservationStatus=='VU', 'MinWingspan']
x6 = filteredBirds.loc[filteredBirds.ConservationStatus=='LC', 'MinWingspan']

kwargs = dict(alpha=0.5, bins=20)

plt.hist(x1, **kwargs, color='red', label='Extinct')
plt.hist(x2, **kwargs, color='orange', label='Critically Endangered')
plt.hist(x3, **kwargs, color='yellow', label='Endangered')
plt.hist(x4, **kwargs, color='green', label='Near Threatened')
plt.hist(x5, **kwargs, color='blue', label='Vulnerable')
plt.hist(x6, **kwargs, color='gray', label='Least Concern')

plt.gca().set(title='Conservation Status', ylabel='Min Wingspan')
plt.legend();

# %% [markdown]
# Test other elements of the dataset using this method. You can try different filters as well

# %%
filteredBirds = birds[(birds['MaxLength'] < 60)]    
x1 = filteredBirds.loc[filteredBirds.ConservationStatus=='EX', 'MaxLength']
x2 = filteredBirds.loc[filteredBirds.ConservationStatus=='CR', 'MaxLength']
x3 = filteredBirds.loc[filteredBirds.ConservationStatus=='EN', 'MaxLength']
x4 = filteredBirds.loc[filteredBirds.ConservationStatus=='NT', 'MaxLength']
x5 = filteredBirds.loc[filteredBirds.ConservationStatus=='VU', 'MaxLength']
x6 = filteredBirds.loc[filteredBirds.ConservationStatus=='LC', 'MaxLength']

kwargs = dict(alpha=0.5, bins=20)

plt.hist(x1, **kwargs, color='red', label='Extinct')
plt.hist(x2, **kwargs, color='orange', label='Critically Endangered')
plt.hist(x3, **kwargs, color='yellow', label='Endangered')
plt.hist(x4, **kwargs, color='green', label='Near Threatened')
plt.hist(x5, **kwargs, color='blue', label='Vulnerable')
plt.hist(x6, **kwargs, color='gray', label='Least Concern')

plt.gca().set(title='Conservation Status', ylabel='MaxLength')
plt.legend();

# %%
filteredBirds = birds[(birds['MaxWingspan'] < 70)]    
x1 = filteredBirds.loc[filteredBirds.ConservationStatus=='EX', 'MaxWingspan']
x2 = filteredBirds.loc[filteredBirds.ConservationStatus=='CR', 'MaxWingspan']
x3 = filteredBirds.loc[filteredBirds.ConservationStatus=='EN', 'MaxWingspan']
x4 = filteredBirds.loc[filteredBirds.ConservationStatus=='NT', 'MaxWingspan']
x5 = filteredBirds.loc[filteredBirds.ConservationStatus=='VU', 'MaxWingspan']
x6 = filteredBirds.loc[filteredBirds.ConservationStatus=='LC', 'MaxWingspan']

kwargs = dict(alpha=0.5, bins=20)

plt.hist(x1, **kwargs, color='red', label='Extinct')
plt.hist(x2, **kwargs, color='orange', label='Critically Endangered')
plt.hist(x3, **kwargs, color='yellow', label='Endangered')
plt.hist(x4, **kwargs, color='green', label='Near Threatened')
plt.hist(x5, **kwargs, color='blue', label='Vulnerable')
plt.hist(x6, **kwargs, color='gray', label='Least Concern')

plt.gca().set(title='Conservation Status', ylabel='MaxWingspan')
plt.legend();

# %% [markdown]
# Working with Seaborn, create a smooth plot about MinWingspan

# %%
import seaborn as sns
import matplotlib.pyplot as plt
filteredBirds = birds[(birds['MaxBodyMass'] > 1) & (birds['MaxBodyMass'] < 60)]    
sns.kdeplot(filteredBirds['MinWingspan'])
plt.show()

# %% [markdown]
# Try a kdeplot about MaxBodyMass

# %%
sns.kdeplot(filteredBirds['MaxBodyMass'])
plt.show()

# %% [markdown]
# Experiment with the plot smoothing parameter

# %%
sns.kdeplot(filteredBirds['MaxBodyMass'], bw_adjust=.2)
plt.show()

# %% [markdown]
# This type of chart offers beautifully explanatory visualizations. With a few lines of code, for example, you can show the max body mass density per bird Order:

# %%
sns.kdeplot(
   data=filteredBirds, x="MaxBodyMass", hue="Order",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# C:\Users\KyDN\AppData\Local\Temp\ipykernel_18268\1933666654.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# <Axes: xlabel='MaxBodyMass', ylabel='Density'>

# %% [markdown]
# Create a 2D kdeplot comparing MinLength and MaxLength with hue showing ConservationStatus

# %%
sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# Out:
# C:\Users\KyDN\AppData\Local\Temp\ipykernel_18268\3552151722.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# <Axes: xlabel='MinLength', ylabel='MaxLength'>
